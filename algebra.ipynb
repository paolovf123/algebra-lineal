# %%
##graficar vectores
import numpy as np
import matplotlib.pyplot as plt

# %%
v1 = np.array([1,4])
v2 = np.array([1,2])

# %%
# %run graficar.py

# %%
graficar_vectores([v1,v2],['orange','blue'])
plt.xlim(-1,8)
plt.ylim(-1,8)
# Out:
# [0 0 1 2]
# (-1.0, 8.0)

# %%
# %matplotlib inline
v1_v2= 2*v1 + 3*v2
graficar_vectores([v1, v2, v1_v2],['gray', 'blue', 'orange'])
plt.xlim(0,15)
plt.ylim(0,15)
# Out:
# [ 0  0  5 14]
# (0.0, 15.0)

# %%
espacio_generado_2d([v1,v2])

# %%
v3 = np.array([1,0])
v4 = np.array([0,1])
espacio_generado_2d([v3,v4])

# %%
from mpl_toolkits.mplot3d import Axes3D
v1_3d = [1,1,0]
v2_3d = [0,1,1]
v3_3d = [0,0,0]
espacio_generado_3d([v1_3d,v2_3d,v3_3d])
